# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvan487/Week1/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Solar Power Output using Linear Regression

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Load Dataset
df=pd.read_csv(r"/content/solarpowergeneration.csv")
#Print first five records
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
#Print first ten records
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
#Print last five record
df.tail()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 3664                       8.58                               93
# 3665                       8.55                               92
# 3666                       9.86                               86
# 3667                      12.00                               81
# 3668                      13.70                               64
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 3664                       1022.3                      0.0
# 3665                       1022.6                      0.0
# 3666                       1023.0                      0.0
# 3667                       1023.3                      0.0
# 3668                       1023.0                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 3664                  0.0                  100.0
# 3665                  0.0                  100.0
# 3666                  0.0                  100.0
# ...

# %%
#Summarize
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                3669.000000                      3669.000000
# mean                   15.822303                        50.451349
# std                     9.024466                        23.596969
# min                    -5.350000                         7.000000
# 25%                     9.020000                        31.000000
# 50%                    15.630000                        47.000000
# 75%                    22.580000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  3669.000000              3669.000000
# mean                   1018.090542                 0.035650
# std                       6.473166                 0.181353
# min                     997.500000                 0.000000
# 25%                    1014.100000                 0.000000
# ...

# %%
#Transpose
df.describe().T

# %%
#Number of rows and columms
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3669 entries, 0 to 3668
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          3669 non-null   float64
#  1   relative_humidity_2_m_above_gnd    3669 non-null   int64
#  2   mean_sea_level_pressure_MSL        3669 non-null   float64
#  3   total_precipitation_sfc            3669 non-null   float64
#  4   snowfall_amount_sfc                3669 non-null   float64
#  5   total_cloud_cover_sfc              3669 non-null   float64
#  6   high_cloud_cover_high_cld_lay      3669 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     3669 non-null   int64
#  8   low_cloud_cover_low_cld_lay        3669 non-null   int64
#  9   shortwave_radiation_backwards_sfc  3669 non-null   float64
#  10  wind_speed_10_m_above_gnd          3669 non-null   float64
# ...

# %%
df.isnull()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 3664                      False                            False
# 3665                      False                            False
# 3666                      False                            False
# 3667                      False                            False
# 3668                      False                            False
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 0                           False                    False
# 1                           False                    False
# ...

# %%
df.isnull().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3664    False
# 3665    False
# 3666    False
# 3667    False
# 3668    False
# Length: 3669, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print("Mean:",df['generated_power_kw'].mean())
# Out:
# Mean: 1132.8444890161293

# %%
print("Median:",df['generated_power_kw'].median())
# Out:
# Median: 979.84961

# %%
print("TOTAL :",df['generated_power_kw'].sum())
# Out:
# TOTAL : 4156406.430200178

# %%
print("kurtosis:",df['generated_power_kw'].kurt())
# Out:
# kurtosis: -1.3407197979110228

# %%
print("Skewness :",df['generated_power_kw'].skew())
# Out:
# Skewness : 0.3350485539777428

# %%
 import matplotlib.pyplot as plt
fig = plt.figure(figsize =(18, 20))
sns.histplot(df['generated_power_kw'], bins =30, kde =True)
plt.title('Solar Power Generated')
plt.xlabel('Power Energy (Kw)')
plt.ylabel('Frequency')
plt.show()
